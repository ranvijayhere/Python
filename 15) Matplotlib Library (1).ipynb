# %% [markdown]
# # __15) Matpotlib Library__
# ## Data Visualization :

# %% [markdown]
# ##  What is Matplotlib?
# #### _Matplotlib is a low level graph plotting library in python that serves as a visualization utility._
#
# #### _Matplotlib was created by John D. Hunter._
#
# #### _Matplotlib is open source and we can use it freely_.
#
# #### _Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility._

# %% [markdown]
# ## Where is the Matplotlib Codebase?
# #### _The source code for Matplotlib is located at this github repository https://github.com/matplotlib/matplotlib_

# %% [markdown]
# ### Installation of Matplotlib
# ##### _If you have Python and PIP already installed on a system, then installation of Matplotlib is very easy._

# %%
C:\Users\Your Name>pip install matplotlib

# %% [markdown]
# ## Import Matplotlib
# #### _Once Matplotlib is installed, import it in your applications by adding the import module statement :_

# %% [markdown]
# ## Checking Matplotlib Version
# #### _The version string is stored under version attribute._

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.9.2

# %% [markdown]
# ## Matplotlib Pyplot
# #### _Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias :_

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib - Line graphs - [Linear graphs]

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4])  # X-axis 
y = x*2  # Y-axis

plt.plot(x, y)  
plt.show()

# %% [markdown]
# ## Plotting x and y points
# ### _The plot() function is used to draw points (markers) in a diagram._
#
# ##### _By default, the plot() function draws a line from point to point._
# ##### _The function takes parameters for specifying points in the diagram._
# ##### _Parameter 1 is an array containing the points on the x-axis._
# ##### _Parameter 2 is an array containing the points on the y-axis._
# ##### _If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function._

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ##### _The x-axis is the horizontal axis._
#
# ##### _The y-axis is the vertical axis._

# %% [markdown]
# ## Plotting Without Line
# ##### _To plot only the markers, you can use shortcut string notation parameter '__o__', which means '__rings__'._

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# ## Multiple Points
# ##### _You can plot as many points as you like, just make sure you have the same number of points in both axis._

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## Default X-Points
# ##### _If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points._

# %%
ypoints = [3, 8, 1, 10, 5, 7]

plt.plot(ypoints)
plt.show()

# %% [markdown]
# ## Markers
# ##### _You can use the keyword argument marker to emphasize each point with a specified marker :_

# %%
ypoints = [3, 8, 1, 10]

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
Marker Reference
You can choose any of these markers :


'o'	Circle	           '*' Star	            '.'	Point	        ',' Pixel	        'x'	X	       'X'	  X (filled)	  '+'	Plus


'P' Plus (filled)	   's' Square	        'D'	Diamond	       'd'	Diamond (thin)	'p'	Pentagon	'H'	Hexagon	

'h'	Hexagon	           'v' Triangle Down	'^'	Triangle Up	'<'	Triangle Left	'>'	Triangle Right	

'1'	Tri Down	       '2' Tri Up	        '3'	Tri Left	    '4'	Tri Right	      '|'	Vline	     '_'	Hline

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# ## Line Reference
# #### _'-'	Solid line ,	':'	Dotted line	 , '--' 	Dashed line	, '-.'	Dashed/dotted line_

# %% [markdown]
# ## Color Reference:
# #### _'r'	Red	, 'g'	Green	, 'b'	Blue ,  'c'	Cyan , 'm'	Magenta	, 'y'	Yellow	,'k' Black ,  'w'	White_

# %% [markdown]
# ## Marker Size - [ ms ]
# #### _You can use the keyword argument markersize or the shorter version, __ms__ to set the size of the markers:_

# %%
ypoints = [3, 8, 1, 10]

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# ## Marker Edge Color - [ mec]
# #### _You can use the keyword argument markeredgecolor or the shorter __mec to set the color__ of the edge of the markers:_

# %%
ypoints = [3, 8, 1, 10]

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
ypoints = [3, 8, 1, 10]

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# #### _Use both the __mec__ and __mfc__ arguments to color the entire marker :_

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# ## Matplotlib Labels and Title
# ##### _With Pyplot, you can use the __xlabel() and ylabel()__ functions to set a label for the __x- and y-axis___.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## Create a Title for a Plot
# ##### _With Pyplot, you can use the __title()__ function to set a title for the plot._

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = [3, 7]             # x1 , x2
ypoints = [5, 7]             # y1 , y2

                     # setting up the size of the graph
plt.figure(figsize=(5,3))

                     # lets have titles and names for axis
plt.title('a simple graph representing a line')
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')

                          # draws a line plot
plt.plot(xpoints, ypoints, marker='o', color='r', ms = 10, mfc = 'b', mec='yellow')
plt.show()

# %% [markdown]
# ## Setup the Title Position
# ##### _You can use the loc parameter in __title()__ to position the title._
# ##### _Legal values are : __' left ' , ' right ' , and ' center '.__ Default value is __' center '__ ._

# %%
x = [80, 85, 90, 95, 100, 105, 110, 115, 120, 125]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Linestyle
# #### _You can use the keyword argument __linestyle, or shorter ls__ , to change the style of the plotted line :_

# %% [markdown]
# ## Line Styles
# #### _'solid' (default)	' - '	 , 'dotted'	' : '	 , 'dashed'	' -- '	 , 'dashdot'	' -. '	 , 'None'	''   or  ' '_

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# ## Line Color
# #### _You can use the keyword argument __color or the shorter c__ to set the color of the line :_

# %% [markdown]
# ## Line Width
# ##### _You can use the keyword argument __linewidth or the shorter lw__ to change the width of the line._

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r' , linewidth = 20.5 )
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = [3, 7]              # x1 , x2
ypoints = [5, 7]              # y1 , y2

                         # setting up the size of the graph
plt.figure(figsize=(5,3))

                         # lets have titles and names for axis
plt.title('a simple graph representing a line')
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')

                         # draws a line plot
plt.plot(xpoints, ypoints, marker='o', color='r', ms = 10, mfc = 'b', mec='yellow', ls=':' , lw = 2.5)
plt.show()

# %% [markdown]
# ## Multiple Lines
# ##### _You can plot as many lines as you like by simply adding more __plt.plot()__ functions:_

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = [3, 8, 1, 10]
y2 = [6, 2, 7, 11]

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# ##### _You can also plot many lines by adding the points for the __x- and y-axis__ for each line in the same __plt.plot()__ function._

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# ## Add Grid Lines to a Plot
# ##### _With Pyplot , you can use the __grid()__ function to __add grid lines__ to the plot._

# %%
x = [80, 85, 90, 95, 100, 105, 110, 115, 120, 125]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]

plt.figure(figsize= (8,3))
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y )
plt.grid(axis = 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [23,34,45,56,65,68,78,79,76]
y = [99,898,68,717,65,646,43,55,344]

plt.figure(figsize =(8,3))

plt.title("Sales Data Analysis", loc = 'left')

plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")

plt.plot(x, y, marker = '+', ms = 14, mfc = 'b', mec = 'r', lw = '1.2', c = 'g', ls = 'dashed')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = [3, 7, 6]     # x1,x2,x3
ypoints = [5, 7, 6 ]    # y1,y2,y3
                                 #s etting up the size of the graph
plt.figure(figsize=(5,3))
                                  # lets have titles and names for axis
plt.title('a simple graph representing a line')
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')

                   # draws a line plot
plt.grid()
plt.plot(ypoints, xpoints, marker='o', color='g', ms = 10, mfc = 'b', mec='yellow', ls='--', lw=3.5)
plt.plot(xpoints, ypoints, marker='o', color='r', ms = 10, mfc = 'b', mec='yellow', ls='--', lw=5)
plt.show()

# %% [markdown]
# #### _You can use the __axis__ parameter in the __grid() function__ to specify which grid lines to display_ .

# %% [markdown]
# # Fill the Area Between Two Lines
# #### _Using the __pyplot.fill_between()__ function we can fill in the region between two line plots in the same graph._

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4])
y = x*2

plt.plot(x, y)

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

plt.plot(x, y1, '-.')
plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('multiple plots', loc = 'left')

plt.fill_between(x, y, y1, color = 'green', alpha = 0.5)
plt.show()

# %% [markdown]
# # __Subplot()__
# #### _With the __subplot()__ function you can draw multiple plots in one figure:_
# #### _The __subplot() function__ takes three arguments that describes the layout of the figure._

# %%
import matplotlib.pyplot as plt
import numpy as np
                              # plot 1 :
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
                               # plot 2 :
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
                                # plot 1 :
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x,y)
                                # plot 2 :
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # __Creating Scatter Plots__
# #### _With Pyplot, you can use the scatter() function to draw a scatter plot ._
# #### _The __scatter() function__ plots one dot for each observation. It needs two arrays of the same length, one for the values of the __x-axis__ , and one for values on the __y-axis__ :_

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
                                              # day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
                                              # day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'Blue')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = 'Red')
plt.show()

# %% [markdown]
# #### _You can even set a specific color for each dot by using an array of colors as value for the c argument :_

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors = ["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"]

plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ## ColorMap
# #### _The Matplotlib module has a number of available colormaps._
# #### _A colormap is like a list of colors, where each color has a value that ranges from 0 to 100 ._
# #### _This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color._

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap ='viridis')          # cmap - [ colormap ]

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap ='viridis')          # cmap - [ colormap ]

plt.colorbar()
plt.show()

# %% [markdown]
# ## Size
# #### _the array for sizes has the same length as the arrays for the x- and y-axis :_

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# ## Alpha
# ##### _You can adjust the transparency of the dots with the alpha argument._

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.7)

plt.show()

# %% [markdown]
# ## Color Size and Alpha
# #### _You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent :_

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap = 'nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # __matplotlib.pyplot.stem()__ - [ stem plot ]
# ### _matplotlib.__pyplot.stem()__ creates stem plots. A Stem plot plots vertical lines at each x position covered under the graph from the baseline to y, and places a marker there._

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x, y)
plt.show()

# %%
markerline, stemlines, baseline = plt.stem(
    x, y, linefmt='grey', markerfmt='D', bottom=1.1)
markerline.set_markerfacecolor('none')
plt.show()

# %% [markdown]
# # Step Plot
# ### _A step plot in Matplotlib visualizes data points by connecting them with horizontal and vertical lines, forming a series of "steps." This type of plot is particularly useful for representing data that remains constant over intervals and changes abruptly at specific points, such as piecewise constant functions or discrete data._

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [2, 5, 3, 7, 4]

plt.step(x, y)
plt.step(x, y, where = 'post')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Matplotlib Step Plot")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 1, 3, 5])

# Creating a basic step plot
plt.step(x, y, where='mid', color='blue', label='Step Plot')

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic Step Plot')

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(14)
y = np.sin(x / 2)

plt.step(x, y + 2, label='pre (default)')
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.3)

plt.step(x, y + 1, where='mid', label='mid')
plt.plot(x, y + 1, 'o--', color='grey', alpha=0.3)

plt.step(x, y, where='post', label='post')
plt.plot(x, y, 'o--', color='grey', alpha=0.3)

plt.grid(axis='x', color='0.95')
plt.legend(title='Parameter where:')
plt.title('plt.step(where=...)')
plt.show()

# %%
plt.plot(x, y + 2, drawstyle='steps', label='steps (=steps-pre)')
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.3)

plt.plot(x, y + 1, drawstyle='steps-mid', label='steps-mid')
plt.plot(x, y + 1, 'o--', color='grey', alpha=0.3)

plt.plot(x, y, drawstyle='steps-post', label='steps-post')
plt.plot(x, y, 'o--', color='grey', alpha=0.3)

plt.grid(axis='x', color='0.95')
plt.legend(title='Parameter drawstyle:')
plt.title('plt.plot(drawstyle=...)')
plt.show()

# %% [markdown]
# # __Creating Bars__ - [ Bar Plot ]
# #### _With Pyplot, you can use the __bar() function__ to draw bar graphs :_

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal Bars
# ##### _If you want the bars to be displayed horizontally instead of vertically, use the __barh() function___:

# %%
x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Bar Color
# #### _The __bar() and barh()__ take the keyword argument color to set the color of the bars :_

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color = "hotpink")
plt.show()

# %% [markdown]
# ## Bar Width
# #### _The __bar()__ takes the keyword argument width to set the width of the bars:_

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# ## Bar Height
# #### _The __barh()__ takes the keyword argument height to set the height of the bars_ :

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# # __Histogram__ - [ Hist Plot ]
# #### _A histogram is a graph showing frequency distributions_ .
# #### _It is a graph showing the number of observations within each given interval_.
# ## Create Histogram
# #### _In Matplotlib , we use the __hist() function__ to create histogram_ .
# ##### _The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument._

# %%
import numpy as np

x = np.random.normal(100, 10, 150)    # This will generate a random result 

print(x)
# Out:
# [ 85.34432537 112.36643152 113.86027669  88.73414305 121.81428237
#  120.5045874  109.22259479 107.07439531 117.05538884  84.66724126
#  106.65378427  97.28706621 101.06706326  99.12757465 110.29812365
#   98.83341653 103.60279638  91.10743933  81.752031    88.01271899
#   98.95953128 104.92799041 103.27937166 104.27318486 101.16679561
#   98.23334504 103.23961727  94.11481311  95.72074665 112.96777782
#  100.49007119  97.92479042  88.24930155  88.84295288  87.70492123
#   94.8816283  114.56638235 119.78195394  95.38846469 110.82179532
#   98.42276689 106.3395403   94.71205179  90.05022871  85.47598589
#  106.3042775  105.01481227 110.71078036 101.03897754 100.68860221
#  102.21029951 101.81498638  98.29951134 107.59477911 102.23994698
#   97.01946263  99.51151047  97.90248205  99.35280404 104.56306402
#   89.96270768 102.51081467 100.32610224 129.2958573   85.9910073
#  115.58326598 117.39207824  98.31746814  92.84222814 107.78460556
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# # __Pie Charts__ -[ Pie Plot ]
# #### _With Pyplot, you can use the __pie() function__ to draw pie charts:_

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# #### _As you can see the pie chart draws one piece ( called a __wedge__ )_)

# %%
                                            # adding labels 
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## Start Angle
# ### _As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter._
# #### _The startangle parameter is defined with an angle in degrees, default angle is 0 :_

# %%
import matplotlib.pyplot as plt
import numpy as np

y = [55, 35, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# ## Explode
# #### _Maybe you want one of the wedges to stand out? The explode parameter allows you to do that_.
# #### _The explode parameter, if specified, and not None, must be an array with one value for each wedge._

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0.1, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Shadow
# #### _Add a shadow to the pie chart by setting the shadows parameter to True :_

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## Colors
# #### _You can set the color of each wedge with the colors parameter._
# ##### _The colors parameter, if specified, must be an array with one value for each wedge_ .

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ##  Legend
# #### _To add a list of explanation for each wedge, use the __legend() function__ :_

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ### Legend With Header
# ##### _To add a header to the legend, add the title parameter to the legend function._

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# # __Box Plot__
# ### _A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of numerical data through its quartiles. In Matplotlib, box plots can be generated using the pyplot.boxplot() function._

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.normal(0, 1, 100)           # Example single dataset
                                           # For multiple box plots:
                                  # data_multiple = [np.random.normal(0, 1, 100), np.random.normal(2, 0.5, 100)]
plt.boxplot(data)
                           # For multiple box plots:
                                 # plt.boxplot(data_multiple)
plt.title('Basic Boxplot')
plt.ylabel('Value')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
d = np.random.normal(100, 20, 200)

fig = plt.figure(figsize =(10, 7))

plt.boxplot(d)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)

d_1 = np.random.normal(100, 10, 200)
d_2 = np.random.normal(90, 20, 200)
d_3 = np.random.normal(80, 30, 200)
d_4 = np.random.normal(70, 40, 200)
d = [d_1, d_2, d_3, d_4]

fig = plt.figure(figsize =(8, 3))
ax = fig.add_axes([0, 0, 1, 1])
ax.boxplot(d)

plt.show()

# %% [markdown]
# # __fill_between_plot__
# ### _To fill the area between plots in Matplotlib, the matplotlib.__pyplot.fill_between()__ function is used. This function allows for shading the region between two horizontal curves or between a curve and a constant y-value (often the x-axis)._

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label='sin(x)')
plt.fill_between(x, y, color='lightblue', alpha=0.5) # Fills between y and y=0
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic fill_between')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label='sin(x)')
plt.plot(x, y2, label='cos(x)')
plt.fill_between(x, y1, y2, color='lightgray', alpha=0.7) # Fills between y1 and y2
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Filling Between Two Curves')
plt.legend()
plt.show()

# %%
x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2 * np.pi * x)
y2 = 0.8 * np.sin(4 * np.pi * x)

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(6, 6))

ax1.fill_between(x, y1)
ax1.set_title('fill between y1 and 0')

ax2.fill_between(x, y1, 1)
ax2.set_title('fill between y1 and 1')

ax3.fill_between(x, y1, y2)
ax3.set_title('fill between y1 and y2')
ax3.set_xlabel('x')
fig.tight_layout()

# %% [markdown]
# # __Importing the CSV Data__

# %%
import pandas as pd

df = pd.read_csv('C:/Users/woake/Python/books.csv')
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  UserRating  Reviews  Price  Year        Genre
# 0                  JJ Smith         4.7    17350      8  2016  Non Fiction
# 1              Stephen King         4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson         4.7    18979     15  2018  Non Fiction
# 3             George Orwell         4.7    21424      6  2017      Fiction
# 4  National Geographic Kids         4.8     7665     12  2019  Non Fiction

# %%
import matplotlib.pyplot as plt

xpoints = [3, 7, 6]               # x1 ,x2 ,x3
ypoints = [5, 7, 6 ]              # y1 ,y2 ,y3
                                    # setting up the size of the graph
plt.figure(figsize=(5,3))

                                   # lets have titles and names for axis
plt.title('a simple graph representing a scatter plot')
plt.xlabel('Genre')
plt.ylabel('UserRating')
                                # draws a line plot
plt.scatter(df['Genre'], df['UserRating'], marker='o', color='g',)
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = [3, 7, 6]    # x1 ,x2 ,x3
ypoints = [5, 7, 6 ]    # y1 ,y2 ,y3
                                     # setting up the size of the graph
plt.figure(figsize=(5,3))
                                    # lets have titles and names for axis
plt.title('a simple graph representing a scatter plot')
plt.xlabel('Genre')
plt.ylabel('Price')
                                           # draws a line plot
plt.scatter(df['Genre'], df['Price'], marker='o', color='hotpink',)
plt.show()

# %%
                                         # making two different sub dataframes
fictional = df[df['Genre']=='Fiction']
non_fictional = df[df['Genre']=='Non Fiction']

# %%
import matplotlib.pyplot as plt

xpoints = [3, 7, 6]       # x1 ,x2, x3
ypoints = [5, 7, 6 ]      # y1, y2, y3
                                                         # setting up the size of the graph
plt.figure(figsize=(5,3))
                                                           # lets have titles and names for axis
plt.title('a simple graph representing a scatter plot')
plt.xlabel('Genre')
plt.ylabel('Price')
                                                                # draws a line plot
plt.scatter(fictional['Genre'], fictional['Price'], marker='o', color='hotpink',)
plt.scatter(non_fictional['Genre'], non_fictional['Price'], marker='o', color='green',)
plt.show()

# %%
fictional.shape
# Out:
# (240, 7)

# %%
non_fictional.shape
# Out:
# (310, 7)

# %%
plt.figure(figsize=(5,3))

gb = df.groupby('Genre')['Name'].count()
gb
                    # draws a bar plot
plt.bar(["Fiction", "Non Fiction"], gb, color='hotpink',)
plt.show()

# %%
gb = df.groupby('Genre')['Name'].count()
plt.figure(figsize=(5,3))
gb.plot(kind='bar', color='yellow')
plt.show()

# %%
age = [23, 26, 35, 54, 32, 41]
salary = [25000,32000,75000,  145000,60000,  89000 ]

plt.figure(figsize=(3,2))
plt.plot(age, salary)
plt.show()

# %%
days = [1,2,3,4,5,6,7]
stock1_price = [280, 292, 288, 251, 243, 272, 289]
stock2_price = [80, 92, 88, 71, 75, 72, 89]


plt.figure(figsize=(6,5))
plt.plot(days, stock1_price,  marker='o')
plt.plot(days, stock2_price,  marker='o')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('C:/Users/woake/Python/books.csv')
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  UserRating  Reviews  Price  Year        Genre
# 0                  JJ Smith         4.7    17350      8  2016  Non Fiction
# 1              Stephen King         4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson         4.7    18979     15  2018  Non Fiction
# 3             George Orwell         4.7    21424      6  2017      Fiction
# 4  National Geographic Kids         4.8     7665     12  2019  Non Fiction

# %%
plt.hist(df['UserRating'])
plt.show()

# %%
y = np.array([35, 25, 25, 15])

plt.figure(figsize=(5,3))
plt.pie(y, counterclock=False)
plt.show()

# %%
gb = df.groupby('UserRating')['UserRating'].count()
titles = np.array( gb.index)
titles
# Out:
# UserRating
# 3.3      1
# 3.6      1
# 3.8      2
# 3.9      3
# 4.0     14
# 4.1      6
# 4.2      8
# 4.3     25
# 4.4     38
# 4.5     60
# 4.6    105
# 4.7    108
# 4.8    127
# 4.9     52
# Name: UserRating, dtype: int64

# %%
gb.plot(kind='pie', figsize=(8,8), title='A  simple graph', labels=titles, legend=True)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0.1, 0, 0]

plt.figure(figsize=(3,3))
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()
